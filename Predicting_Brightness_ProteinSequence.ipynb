# %% [markdown]
# # GFP Sequence to Function Model
#
# Code adapted from [David Brookes' CbAS](https://github.com/MauriceR71/CbAS-Restored)

# %%
# !git clone https://github.com/igemto-drylab/lec6.git
# %cd lec6
# Out:
# Cloning into 'lec6'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# /content/lec6/lec6

# %%
import keras
from keras.layers import Input, Dense, Reshape, Flatten
from keras import layers, initializers
from keras.models import Model, load_model
import keras.backend as K
import numpy as np
from keras.callbacks import EarlyStopping
import pandas as pd
import random

# %%
data_df = pd.read_csv("gfp_data.csv")

# %%
data_df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  nucSequence  numNucMutations  \
# 0           0             0               0          NaN                0
# 1           1             1               1          NaN                1
# 2           2             2               2          NaN                1
# 3           3             3               3          NaN                2
# 4           4             4               4          NaN                2
#
#    numAAMutations  uniqueBarcodes  medianBrightness       std  \
# 0               0            2444          3.718386  0.111561
# 1               0               2          3.622869  0.145991
# 2               0              25          3.722241  0.112935
# 3               0               1          3.697823  0.000000
# 4               0               1          3.804003  0.000000
#
#                                           aaSequence
# 0  skgeelftgvvpilveldgdvnghkfsvsgegegdatygkltlkfi...
# 1  skgeelftgvvpilveldgdvnghkfsvsgegegdatygkltlkfi...
# 2  skgeelftgvvpilveldgdvnghkfsvsgegegdatygkltlkfi...
# 3  skgeelftgvvpilveldgdvnghkfsvsgegegdatygkltlkfi...
# 4  skgeelftgvvpilveldgdvnghkfsvsgegegdatygkltlkfi...

# %%
random.seed(1)

AA = ['a', 'r', 'n', 'd', 'c', 'q', 'e', 'g', 'h', 'i', 'l', 'k', 'm', 'f', 'p', 's', 't', 'w', 'y', 'v', 'x']
AA_upper = []
for m_aa in AA:
    AA_upper.append(m_aa.upper())
  
AA_IDX = {AA_upper[i]:i for i in range(len(AA_upper))}

def one_hot_encode_aa(aa_str):
    M = len(aa_str)
    aa_arr = np.zeros((M, 21), dtype=int)
    for i in range(M):
        aa_arr[i, AA_IDX[aa_str[i].upper()]] = 1
    return aa_arr

# %%
def get_data(train_size, ignore_stops=True):
    data_df = pd.read_csv("gfp_data.csv")

    idx = data_df.index
    data_df = data_df.loc[idx]
    
    if ignore_stops:
        idx = data_df.loc[~data_df['aaSequence'].str.contains('!')].index
    data_df = data_df.loc[idx]

    seqs = data_df['aaSequence']
      
    M = len(seqs[0])
    N = len(seqs)
    X = np.zeros((N, M, 21))
    j = 0
    for i in idx:
        X[j] = one_hot_encode_aa(seqs[i])
        j += 1
    y = np.array(data_df['medianBrightness'][idx])

    # zip and shuffle data
    data_list = list(zip(X, y))
    random.shuffle(data_list)
    X, y = zip(*data_list)

    return np.array(X)[:train_size], np.array(y)[:train_size]

# %%
def build_model(M):
    x = Input(shape=(M, 21,))
    y = Flatten()(x)
    y = Dense(50, activation='elu')(y)
    y = Dense(2)(y)
    model = Model(inputs=x, outputs=y)
    return model

# %%
def neg_log_likelihood(y_true, y_pred):
    y_true = y_true[:, 0]
    mean = y_pred[:, 0]
    variance = K.softplus(y_pred[:, 1]) + 1e-6
    log_variance = K.log(variance)
    return 0.5 * K.mean(log_variance, axis = -1) + 0.5 * K.mean(K.square(y_true - mean) / variance, axis = -1) + 0.5 * K.log(2 * np.pi)

# %%
def train_oracles_helper(X_train, y_train, num_models, batch_size=25):
    for i in range(num_models):
        model = build_model(X_train.shape[1])
        model.compile(optimizer='adam',
                      loss=neg_log_likelihood,
                      )
        early_stop = EarlyStopping(monitor='val_loss', 
                                   min_delta=0, 
                                   patience=5, 
                                   verbose=1)
        # print(model.summary())
        model.fit(X_train, y_train, 
                  epochs=40, 
                  batch_size=batch_size, 
                  validation_split=0.1, 
                  callbacks=[early_stop],
                  verbose=2)
        model.save("/content/lec6/oracle_model_%i.h5" % i)

# %%
def train_oracles():
    i = 1
    num_models = 5
    for i in range(num_models):
        X_train, y_train = get_data(train_size=10000)  # data has 58417 seqs
        
        suffix = '_%i' % num_models
        train_oracles_helper(X_train, y_train, num_models, batch_size=64)

# %%
def make_prediction():
    for i in range(num_models):
        vec = np.array([one_hot_encode_aa(s)])
        model = load_model("/content/lec6/oracle_model_%i.h5" % i)
        predictions.append(model.predict(vec))
    print(predictions)

# %%
train_oracles()
# Out:
# Epoch 1/40
# 141/141 - 1s - loss: 1.5991 - val_loss: 1.1969 - 1s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0346 - val_loss: 0.9650 - 729ms/epoch - 5ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8701 - val_loss: 0.8849 - 767ms/epoch - 5ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7660 - val_loss: 1.0451 - 748ms/epoch - 5ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7332 - val_loss: 0.7734 - 736ms/epoch - 5ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6387 - val_loss: 0.7515 - 761ms/epoch - 5ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5707 - val_loss: 0.7768 - 901ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6425 - val_loss: 0.8374 - 777ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5073 - val_loss: 0.7245 - 728ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5011 - val_loss: 0.8034 - 810ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4486 - val_loss: 0.8192 - 865ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4196 - val_loss: 0.8685 - 776ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.6079 - val_loss: 0.7203 - 744ms/epoch - 5ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4173 - val_loss: 0.9878 - 837ms/epoch - 6ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.3718 - val_loss: 1.1413 - 910ms/epoch - 6ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.3841 - val_loss: 0.9834 - 930ms/epoch - 7ms/step
# Epoch 17/40
# 141/141 - 1s - loss: 0.3834 - val_loss: 1.1482 - 918ms/epoch - 7ms/step
# Epoch 18/40
# 141/141 - 1s - loss: 0.3520 - val_loss: 2.0165 - 941ms/epoch - 7ms/step
# Epoch 18: early stopping
# Epoch 1/40
# 141/141 - 3s - loss: 1.5028 - val_loss: 1.1529 - 3s/epoch - 20ms/step
# Epoch 2/40
# 141/141 - 2s - loss: 0.9830 - val_loss: 0.9615 - 2s/epoch - 15ms/step
# Epoch 3/40
# 141/141 - 2s - loss: 0.8160 - val_loss: 0.8263 - 2s/epoch - 13ms/step
# Epoch 4/40
# 141/141 - 2s - loss: 0.7422 - val_loss: 0.7822 - 2s/epoch - 16ms/step
# Epoch 5/40
# 141/141 - 2s - loss: 0.6556 - val_loss: 0.7966 - 2s/epoch - 15ms/step
# Epoch 6/40
# 141/141 - 2s - loss: 0.6224 - val_loss: 0.7511 - 2s/epoch - 15ms/step
# Epoch 7/40
# 141/141 - 2s - loss: 0.5852 - val_loss: 0.7083 - 2s/epoch - 17ms/step
# Epoch 8/40
# 141/141 - 2s - loss: 0.6156 - val_loss: 0.9757 - 2s/epoch - 16ms/step
# Epoch 9/40
# 141/141 - 2s - loss: 0.5818 - val_loss: 1.2239 - 2s/epoch - 16ms/step
# Epoch 10/40
# 141/141 - 2s - loss: 0.5157 - val_loss: 0.9083 - 2s/epoch - 15ms/step
# Epoch 11/40
# 141/141 - 2s - loss: 0.4713 - val_loss: 0.8934 - 2s/epoch - 15ms/step
# Epoch 12/40
# 141/141 - 2s - loss: 0.5562 - val_loss: 0.8501 - 2s/epoch - 14ms/step
# Epoch 12: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.6352 - val_loss: 1.3188 - 2s/epoch - 13ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0624 - val_loss: 0.9261 - 792ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8276 - val_loss: 0.8866 - 762ms/epoch - 5ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7602 - val_loss: 0.7819 - 838ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6947 - val_loss: 0.7732 - 843ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6384 - val_loss: 0.7276 - 799ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5580 - val_loss: 0.7650 - 907ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6146 - val_loss: 0.7084 - 780ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.4866 - val_loss: 1.8272 - 772ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4991 - val_loss: 0.8409 - 749ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5051 - val_loss: 0.7890 - 754ms/epoch - 5ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4120 - val_loss: 0.7446 - 892ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4038 - val_loss: 0.7382 - 928ms/epoch - 7ms/step
# Epoch 13: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.5244 - val_loss: 1.1239 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9915 - val_loss: 0.9767 - 887ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8324 - val_loss: 0.8587 - 919ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.8028 - val_loss: 0.8781 - 1s/epoch - 8ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6978 - val_loss: 0.8021 - 952ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6289 - val_loss: 0.7329 - 747ms/epoch - 5ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6216 - val_loss: 0.8711 - 913ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5951 - val_loss: 0.7162 - 808ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5162 - val_loss: 0.7579 - 749ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5862 - val_loss: 0.6997 - 764ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4922 - val_loss: 0.7548 - 893ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4576 - val_loss: 0.9192 - 904ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4387 - val_loss: 0.7489 - 892ms/epoch - 6ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4630 - val_loss: 0.8078 - 893ms/epoch - 6ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.4547 - val_loss: 0.9323 - 882ms/epoch - 6ms/step
# Epoch 15: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.5922 - val_loss: 1.2507 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0365 - val_loss: 0.9979 - 725ms/epoch - 5ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8555 - val_loss: 0.8365 - 723ms/epoch - 5ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7255 - val_loss: 0.9218 - 739ms/epoch - 5ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6748 - val_loss: 0.8701 - 721ms/epoch - 5ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.5958 - val_loss: 1.4022 - 730ms/epoch - 5ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6034 - val_loss: 0.8682 - 719ms/epoch - 5ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5396 - val_loss: 0.7232 - 734ms/epoch - 5ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5038 - val_loss: 1.0023 - 750ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4867 - val_loss: 0.8778 - 768ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4413 - val_loss: 1.5540 - 1s/epoch - 8ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4223 - val_loss: 1.1677 - 1s/epoch - 9ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.3665 - val_loss: 1.4950 - 971ms/epoch - 7ms/step
# Epoch 13: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.6804 - val_loss: 1.2359 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0413 - val_loss: 0.8819 - 774ms/epoch - 5ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.7946 - val_loss: 0.7952 - 785ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.6743 - val_loss: 0.8972 - 800ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6165 - val_loss: 0.8077 - 785ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.5620 - val_loss: 0.9366 - 812ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5913 - val_loss: 0.8218 - 822ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5860 - val_loss: 0.8967 - 953ms/epoch - 7ms/step
# Epoch 8: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.4724 - val_loss: 1.1610 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9908 - val_loss: 0.9304 - 797ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8515 - val_loss: 0.8267 - 784ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7108 - val_loss: 0.7871 - 809ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6429 - val_loss: 1.0372 - 911ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.7186 - val_loss: 0.8537 - 958ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5492 - val_loss: 0.8020 - 928ms/epoch - 7ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5531 - val_loss: 1.2433 - 977ms/epoch - 7ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5539 - val_loss: 1.1905 - 958ms/epoch - 7ms/step
# Epoch 9: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.6266 - val_loss: 1.1964 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9824 - val_loss: 0.9228 - 752ms/epoch - 5ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8315 - val_loss: 0.8594 - 847ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7684 - val_loss: 0.8356 - 842ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6472 - val_loss: 0.7693 - 783ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6989 - val_loss: 0.8001 - 930ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6375 - val_loss: 1.0881 - 958ms/epoch - 7ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5875 - val_loss: 0.8369 - 729ms/epoch - 5ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5109 - val_loss: 0.8868 - 857ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5419 - val_loss: 0.9014 - 870ms/epoch - 6ms/step
# Epoch 10: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.5712 - val_loss: 1.1461 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9664 - val_loss: 0.9158 - 894ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8376 - val_loss: 0.9292 - 967ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7158 - val_loss: 0.9522 - 947ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6765 - val_loss: 0.9787 - 881ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.5981 - val_loss: 0.7975 - 882ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.9354 - val_loss: 0.8884 - 803ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5839 - val_loss: 0.9353 - 938ms/epoch - 7ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5306 - val_loss: 0.8797 - 835ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5450 - val_loss: 1.1333 - 770ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4927 - val_loss: 0.8386 - 796ms/epoch - 6ms/step
# Epoch 11: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.4368 - val_loss: 1.0910 - 2s/epoch - 12ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9918 - val_loss: 0.9003 - 852ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8241 - val_loss: 0.9065 - 826ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7191 - val_loss: 0.9035 - 968ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7478 - val_loss: 0.8028 - 905ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6209 - val_loss: 0.7686 - 930ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5850 - val_loss: 0.8036 - 1s/epoch - 8ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5705 - val_loss: 0.7536 - 966ms/epoch - 7ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5878 - val_loss: 1.2409 - 916ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4697 - val_loss: 0.8695 - 956ms/epoch - 7ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5098 - val_loss: 1.6119 - 834ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.5338 - val_loss: 1.3083 - 854ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4003 - val_loss: 0.9584 - 843ms/epoch - 6ms/step
# Epoch 13: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.7076 - val_loss: 1.1707 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0229 - val_loss: 1.0591 - 793ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8489 - val_loss: 0.8563 - 836ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7492 - val_loss: 0.7724 - 903ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6866 - val_loss: 0.8472 - 783ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6824 - val_loss: 0.8394 - 790ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5668 - val_loss: 0.7659 - 781ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5160 - val_loss: 0.7507 - 765ms/epoch - 5ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5766 - val_loss: 0.7408 - 787ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4594 - val_loss: 0.7574 - 794ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5072 - val_loss: 0.8047 - 887ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.5038 - val_loss: 0.7752 - 837ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4079 - val_loss: 0.9200 - 751ms/epoch - 5ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4422 - val_loss: 0.8486 - 787ms/epoch - 6ms/step
# Epoch 14: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.4859 - val_loss: 1.0343 - 2s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9875 - val_loss: 0.8896 - 1s/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8764 - val_loss: 1.1172 - 1s/epoch - 9ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7520 - val_loss: 0.8881 - 1s/epoch - 10ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6963 - val_loss: 0.7818 - 833ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6890 - val_loss: 0.7171 - 794ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6087 - val_loss: 0.7930 - 901ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5534 - val_loss: 0.7857 - 819ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5403 - val_loss: 0.8846 - 766ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5343 - val_loss: 0.7853 - 771ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5563 - val_loss: 0.6639 - 923ms/epoch - 7ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4495 - val_loss: 0.8292 - 930ms/epoch - 7ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4865 - val_loss: 0.8460 - 983ms/epoch - 7ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4212 - val_loss: 0.7462 - 832ms/epoch - 6ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.4176 - val_loss: 1.2091 - 794ms/epoch - 6ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.3903 - val_loss: 0.7467 - 773ms/epoch - 5ms/step
# Epoch 16: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.6087 - val_loss: 1.1940 - 2s/epoch - 12ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0308 - val_loss: 0.9133 - 950ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8645 - val_loss: 0.9718 - 791ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7324 - val_loss: 0.7582 - 967ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7850 - val_loss: 0.9418 - 988ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6087 - val_loss: 0.7866 - 994ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5947 - val_loss: 0.6975 - 983ms/epoch - 7ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5978 - val_loss: 0.7094 - 937ms/epoch - 7ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.4595 - val_loss: 0.7358 - 879ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5494 - val_loss: 0.7784 - 831ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4688 - val_loss: 0.6762 - 919ms/epoch - 7ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4383 - val_loss: 0.6746 - 817ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4413 - val_loss: 0.8342 - 979ms/epoch - 7ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4857 - val_loss: 0.7838 - 976ms/epoch - 7ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.4123 - val_loss: 0.7056 - 963ms/epoch - 7ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.3639 - val_loss: 0.8689 - 964ms/epoch - 7ms/step
# Epoch 17/40
# 141/141 - 1s - loss: 0.3867 - val_loss: 0.9675 - 960ms/epoch - 7ms/step
# Epoch 17: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.5632 - val_loss: 1.1422 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9816 - val_loss: 0.9113 - 974ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8550 - val_loss: 1.2026 - 995ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7412 - val_loss: 0.7865 - 977ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6741 - val_loss: 0.8321 - 817ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6287 - val_loss: 0.8419 - 962ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6037 - val_loss: 0.7245 - 804ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5771 - val_loss: 0.9729 - 782ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5850 - val_loss: 0.8284 - 810ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5622 - val_loss: 1.0623 - 806ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4656 - val_loss: 0.7001 - 813ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4477 - val_loss: 0.7520 - 946ms/epoch - 7ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4640 - val_loss: 0.8015 - 813ms/epoch - 6ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4472 - val_loss: 0.8345 - 780ms/epoch - 6ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.4274 - val_loss: 0.9973 - 824ms/epoch - 6ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.3898 - val_loss: 1.0490 - 939ms/epoch - 7ms/step
# Epoch 16: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.6915 - val_loss: 1.2289 - 2s/epoch - 12ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0406 - val_loss: 0.9283 - 1s/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8655 - val_loss: 0.8459 - 971ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7292 - val_loss: 0.7568 - 839ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6298 - val_loss: 0.7767 - 797ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6138 - val_loss: 0.6973 - 840ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5461 - val_loss: 1.0915 - 960ms/epoch - 7ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5769 - val_loss: 0.7894 - 925ms/epoch - 7ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.4865 - val_loss: 1.0065 - 804ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4937 - val_loss: 0.7396 - 806ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4646 - val_loss: 0.7398 - 917ms/epoch - 7ms/step
# Epoch 11: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.4590 - val_loss: 1.2459 - 2s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0203 - val_loss: 1.1229 - 1s/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8693 - val_loss: 0.9413 - 1000ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7589 - val_loss: 0.8394 - 1s/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7473 - val_loss: 0.9026 - 977ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6660 - val_loss: 0.8124 - 944ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5602 - val_loss: 1.3318 - 906ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5999 - val_loss: 0.8263 - 790ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5330 - val_loss: 1.0474 - 800ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5047 - val_loss: 0.9458 - 791ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5234 - val_loss: 0.9760 - 803ms/epoch - 6ms/step
# Epoch 11: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.5695 - val_loss: 1.2390 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0602 - val_loss: 0.9265 - 799ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8106 - val_loss: 0.9699 - 952ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.6953 - val_loss: 0.8574 - 856ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7059 - val_loss: 0.8484 - 786ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6022 - val_loss: 0.8997 - 831ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6339 - val_loss: 0.8252 - 1s/epoch - 7ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5956 - val_loss: 0.8938 - 992ms/epoch - 7ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5818 - val_loss: 0.8312 - 985ms/epoch - 7ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5468 - val_loss: 0.9902 - 814ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.6605 - val_loss: 1.3461 - 802ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4798 - val_loss: 0.9985 - 779ms/epoch - 6ms/step
# Epoch 12: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.5584 - val_loss: 1.2020 - 2s/epoch - 12ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0059 - val_loss: 1.0078 - 923ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8623 - val_loss: 0.9662 - 806ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7451 - val_loss: 1.0422 - 785ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7227 - val_loss: 0.9830 - 744ms/epoch - 5ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6565 - val_loss: 1.0343 - 732ms/epoch - 5ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5603 - val_loss: 1.0061 - 877ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6080 - val_loss: 0.9117 - 841ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5566 - val_loss: 1.5981 - 737ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5153 - val_loss: 0.9639 - 764ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5343 - val_loss: 0.9576 - 785ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.5127 - val_loss: 1.2188 - 740ms/epoch - 5ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4158 - val_loss: 1.1255 - 754ms/epoch - 5ms/step
# Epoch 13: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.5805 - val_loss: 1.1425 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0199 - val_loss: 1.0189 - 953ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8702 - val_loss: 0.9502 - 958ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7704 - val_loss: 1.4643 - 821ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7603 - val_loss: 0.8629 - 825ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.7098 - val_loss: 0.9118 - 852ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6873 - val_loss: 1.1572 - 827ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6208 - val_loss: 1.0355 - 830ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5708 - val_loss: 0.9210 - 931ms/epoch - 7ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.5524 - val_loss: 0.9579 - 945ms/epoch - 7ms/step
# Epoch 10: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.6169 - val_loss: 1.1599 - 2s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9901 - val_loss: 0.9864 - 829ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8675 - val_loss: 0.9833 - 1s/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7483 - val_loss: 0.8364 - 1s/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7194 - val_loss: 0.9643 - 859ms/epoch - 6ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6284 - val_loss: 1.0553 - 855ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6239 - val_loss: 0.8691 - 840ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5840 - val_loss: 0.8364 - 821ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5490 - val_loss: 0.8415 - 829ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.6108 - val_loss: 0.8990 - 830ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4897 - val_loss: 1.0489 - 807ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4578 - val_loss: 0.9454 - 921ms/epoch - 7ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4776 - val_loss: 1.1054 - 922ms/epoch - 7ms/step
# Epoch 13: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.6993 - val_loss: 1.2106 - 2s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0302 - val_loss: 1.1065 - 968ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8446 - val_loss: 0.9305 - 977ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7696 - val_loss: 1.0716 - 992ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6553 - val_loss: 0.8139 - 933ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6274 - val_loss: 0.7989 - 774ms/epoch - 5ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6056 - val_loss: 0.8050 - 780ms/epoch - 6ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5879 - val_loss: 0.9560 - 763ms/epoch - 5ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.4984 - val_loss: 0.8754 - 755ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4866 - val_loss: 0.7215 - 750ms/epoch - 5ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5120 - val_loss: 0.8568 - 764ms/epoch - 5ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4096 - val_loss: 0.8570 - 785ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4286 - val_loss: 1.8830 - 835ms/epoch - 6ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.5538 - val_loss: 0.9007 - 966ms/epoch - 7ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.3782 - val_loss: 1.1157 - 954ms/epoch - 7ms/step
# Epoch 15: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.6016 - val_loss: 1.1211 - 2s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9643 - val_loss: 1.0816 - 935ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8096 - val_loss: 1.3094 - 958ms/epoch - 7ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7778 - val_loss: 0.9683 - 960ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6733 - val_loss: 0.9495 - 988ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6266 - val_loss: 0.9907 - 983ms/epoch - 7ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6068 - val_loss: 0.8300 - 991ms/epoch - 7ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6226 - val_loss: 0.7688 - 1s/epoch - 9ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5170 - val_loss: 1.1008 - 1s/epoch - 8ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4617 - val_loss: 1.0756 - 806ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5667 - val_loss: 0.7057 - 787ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4033 - val_loss: 0.7679 - 1s/epoch - 9ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.4831 - val_loss: 0.9456 - 1s/epoch - 9ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4046 - val_loss: 0.8695 - 1s/epoch - 7ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.4001 - val_loss: 1.0129 - 960ms/epoch - 7ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.4420 - val_loss: 0.9105 - 955ms/epoch - 7ms/step
# Epoch 16: early stopping
# Epoch 1/40
# 141/141 - 2s - loss: 1.4076 - val_loss: 1.2667 - 2s/epoch - 13ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 0.9788 - val_loss: 1.1178 - 926ms/epoch - 7ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8411 - val_loss: 1.0126 - 787ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.8060 - val_loss: 0.8031 - 784ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.6911 - val_loss: 0.7684 - 928ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.7200 - val_loss: 0.7515 - 829ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6369 - val_loss: 0.7436 - 765ms/epoch - 5ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6255 - val_loss: 0.7568 - 746ms/epoch - 5ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.5378 - val_loss: 0.7552 - 765ms/epoch - 5ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4751 - val_loss: 0.9421 - 812ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5184 - val_loss: 0.8442 - 854ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4885 - val_loss: 0.7021 - 879ms/epoch - 6ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.5234 - val_loss: 1.1902 - 807ms/epoch - 6ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.4331 - val_loss: 0.8754 - 934ms/epoch - 7ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.4961 - val_loss: 0.9001 - 946ms/epoch - 7ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.4266 - val_loss: 0.7587 - 919ms/epoch - 7ms/step
# Epoch 17/40
# 141/141 - 1s - loss: 0.3999 - val_loss: 0.9263 - 959ms/epoch - 7ms/step
# Epoch 17: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.3893 - val_loss: 1.0526 - 1s/epoch - 11ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0103 - val_loss: 0.9168 - 799ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8297 - val_loss: 1.0708 - 777ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.8023 - val_loss: 0.9700 - 808ms/epoch - 6ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7606 - val_loss: 0.8211 - 754ms/epoch - 5ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6321 - val_loss: 0.8606 - 784ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.6259 - val_loss: 0.7330 - 767ms/epoch - 5ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.6180 - val_loss: 0.7667 - 766ms/epoch - 5ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.6253 - val_loss: 0.8095 - 776ms/epoch - 6ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4614 - val_loss: 0.8367 - 776ms/epoch - 6ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.5630 - val_loss: 0.8361 - 798ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.4604 - val_loss: 0.8414 - 919ms/epoch - 7ms/step
# Epoch 12: early stopping
# Epoch 1/40
# 141/141 - 1s - loss: 1.6301 - val_loss: 1.1507 - 1s/epoch - 10ms/step
# Epoch 2/40
# 141/141 - 1s - loss: 1.0262 - val_loss: 0.9205 - 780ms/epoch - 6ms/step
# Epoch 3/40
# 141/141 - 1s - loss: 0.8620 - val_loss: 0.8792 - 812ms/epoch - 6ms/step
# Epoch 4/40
# 141/141 - 1s - loss: 0.7333 - val_loss: 0.7982 - 974ms/epoch - 7ms/step
# Epoch 5/40
# 141/141 - 1s - loss: 0.7020 - val_loss: 0.8502 - 946ms/epoch - 7ms/step
# Epoch 6/40
# 141/141 - 1s - loss: 0.6188 - val_loss: 0.8067 - 916ms/epoch - 6ms/step
# Epoch 7/40
# 141/141 - 1s - loss: 0.5740 - val_loss: 0.7132 - 775ms/epoch - 5ms/step
# Epoch 8/40
# 141/141 - 1s - loss: 0.5448 - val_loss: 0.7112 - 906ms/epoch - 6ms/step
# Epoch 9/40
# 141/141 - 1s - loss: 0.9113 - val_loss: 0.7208 - 968ms/epoch - 7ms/step
# Epoch 10/40
# 141/141 - 1s - loss: 0.4950 - val_loss: 0.6842 - 937ms/epoch - 7ms/step
# Epoch 11/40
# 141/141 - 1s - loss: 0.4556 - val_loss: 0.7663 - 878ms/epoch - 6ms/step
# Epoch 12/40
# 141/141 - 1s - loss: 0.5548 - val_loss: 0.8232 - 754ms/epoch - 5ms/step
# Epoch 13/40
# 141/141 - 1s - loss: 0.3967 - val_loss: 0.8664 - 936ms/epoch - 7ms/step
# Epoch 14/40
# 141/141 - 1s - loss: 0.3997 - val_loss: 0.6704 - 766ms/epoch - 5ms/step
# Epoch 15/40
# 141/141 - 1s - loss: 0.3817 - val_loss: 0.8309 - 766ms/epoch - 5ms/step
# Epoch 16/40
# 141/141 - 1s - loss: 0.3759 - val_loss: 0.7737 - 743ms/epoch - 5ms/step
# Epoch 17/40
# 141/141 - 1s - loss: 0.3376 - val_loss: 0.9829 - 752ms/epoch - 5ms/step
# Epoch 18/40
# 141/141 - 1s - loss: 0.3637 - val_loss: 1.7526 - 784ms/epoch - 6ms/step
# Epoch 19/40
# 141/141 - 1s - loss: 0.3338 - val_loss: 1.0424 - 776ms/epoch - 6ms/step
# Epoch 19: early stopping

# %%
# seq must have the same number of amino acids as those in the training set
# missing amino acids may be denoted by 'x'
seq = ""

make_predictions(seq)
